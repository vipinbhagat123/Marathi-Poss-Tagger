# %%
import requests
from bs4 import BeautifulSoup
import os
import datetime # Import datetime for unique filenames

# Define a User-Agent header to mimic a web browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

def scrape_article(url):
    """
    Scrapes the title and main article content from a given URL.

    Args:
        url (str): The URL of the article to scrape.

    Returns:
        tuple: A tuple containing (title_text, article_text) if successful,
               otherwise (None, None). Prints error messages on failure.
    """
    print(f"\nAttempting to fetch content from: {url}")
    try:
        # Send a GET request to the URL
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        print("Successfully fetched the initial HTML content.")
        print("--- Page Title ---")
        # Attempt to find the main title of the article
        article_title = soup.find('h1')
        title_text = article_title.get_text(strip=True) if article_title else "No title found"
        print(title_text)
        print("------------------")

        # --- Extracting Article Content ---
        print("--- Attempting to extract Marathi News Content ---")

        # Common classes for article body on news websites
        article_body = soup.find('div', class_='article-content') # A common class for article content
        if not article_body:
            article_body = soup.find('div', class_='story-content') # Another common class
        if not article_body:
            article_body = soup.find('div', id='article-body') # Or an ID

        article_text = ""
        if article_body:
            # Extract text from all paragraph tags within the identified article body
            paragraphs = article_body.find_all('p')
            article_text = "\n\n".join([p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True)])

            if article_text:
                print("\nArticle Content Found (first 500 characters):")
                print(article_text[:500] + "..." if len(article_text) > 500 else article_text)
                print("\n--- End of Article Content Snippet ---")
            else:
                print("No readable text paragraphs found within the identified article content area.")
        else:
            print("Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').")
            print("Please inspect the website's HTML structure to find the correct selector for this URL.")

        return title_text, article_text

    except requests.exceptions.HTTPError as errh:
        print(f"HTTP Error for {url}: {errh}")
    except requests.exceptions.ConnectionError as errc:
        print(f"Error Connecting to {url}: {errc}")
    except requests.exceptions.Timeout as errt:
        print(f"Timeout Error for {url}: {errt}")
    except requests.exceptions.RequestException as err:
        print(f"An unexpected error occurred for {url}: {err}")
    return None, None

# %%
if __name__ == "__main__":
    urls_file_name = "/content/links_data_scrapping_24jul.txt"
    output_file_name = "links_file2_data_scrapped_24jul.txt" # Define the single output file

    if not os.path.exists(urls_file_name):
        print(f"Error: File '{urls_file_name}' not found. Please create a text file with one URL per line.")
    else:
        with open(urls_file_name, 'r', encoding='utf-8') as f:
            urls = [line.strip() for line in f if line.strip()] # Read non-empty lines

        if not urls:
            print(f"The file '{urls_file_name}' is empty or contains no valid URLs.")
        else:
            print(f"\nFound {len(urls)} URLs in '{urls_file_name}'. Starting scraping...\n")

            # Open the single output file in append mode
            try:
                with open(output_file_name, "a", encoding="utf-8") as out_f:
                    for i, url_to_scrape in enumerate(urls):
                        print(f"\n--- Processing URL {i+1}/{len(urls)} ---")
                        title, content = scrape_article(url_to_scrape)
                        if title and content:
                            print(f"\nSuccessfully scraped: {title}")
                            # Write to the single output file, separated by title
                            out_f.write(f"{title} \n")
                            out_f.write(content)
                            # out_f.write("\n\n" + "="*80 + "\n\n") # Add a clear separator between articles
                        else:
                            print(f"\nFailed to scrape content from: {url_to_scrape}")
                            out_f.write(f"--- Failed to scrape from: {url_to_scrape} ---\n")
                            out_f.write("No content extracted.\n\n" + "="*80 + "\n\n")
                print(f"\nAll scraped content saved to '{output_file_name}'")
            except IOError as e:
                print(f"Error opening or writing to {output_file_name}: {e}")
# Out:
# Found 85 URLs in '/content/links_data_scrapping_24jul.txt'. Starting scraping...
#
#
# --- Processing URL 1/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/jal
85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/nashik-elder-women-more-than-two-thousand-rakhis-sent-to-soldiers-rakhi-purnima-2025-css-98-5248311/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# सैनिकांना दोन हजारपेक्षा अधिक पर्यावरणपूरक राख्यांची भेट, वयोवृध्द विमलताईंचा उत्साह
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/nashik-elder-women-more-than-two-thousand-rakhis-sent-to-soldiers-rakhi-purnima-2025-css-98-5248311/
#
# --- Processing URL 20/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/jalgaon-district-exported-farm-produce-of-12-thousand-crores-banana-other-fruits-css-98-5248109/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# जळगावमधून १२ हजार कोटींची निर्यात; कृषी आणि अन्न प्रक्रिया क्षेत्राचा मोठा वाटा
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/jalgaon-district-exported-farm-produce-of-12-thousand-crores-banana-other-fruits-css-98-5248109/
#
# --- Processing URL 21/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/thackeray-group-mlas-including-farmers-taken-into-police-custody-for-blocking-highway-work-in-jalgaon-amy-95-5246634/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# जळगावात महामार्गाचे काम रोखले; शेतकऱ्यांसह शिंदे गटाचे आमदार पोलिसांच्या ताब्यात
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/thackeray-group-mlas-including-farmers-taken-into-police-custody-for-blocking-highway-work-in-jalgaon-amy-95-5246634/
#
# --- Processing URL 22/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/during-nashik-visit-cards-thrown-at-manikrao-kokate-by-thackeray-sena-workers-over-rummy-controversy-rds-00-5246145/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# माणिकराव कोकाटे यांच्यावर नाशिकमध्ये ठाकरे गटाकडून पत्ते फेकण्याचा प्रयत्न
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/during-nashik-visit-cards-thrown-at-manikrao-kokate-by-thackeray-sena-workers-over-rummy-controversy-rds-00-5246145/
#
# --- Processing URL 23/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/manikrao-kokate-announced-krishi-samriddhi-yojana-on-occasion-of-birthday-of-devendra-fadnavis-and-ajit-pawar-sud-02-5246390/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# देवेंद्र फडणवीस, अजित पवार यांच्या वाढदिवसानिमित्त माणिक कोकाटे यांची कोणती योजना ?
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/manikrao-kokate-announced-krishi-samriddhi-yojana-on-occasion-of-birthday-of-devendra-fadnavis-and-ajit-pawar-sud-02-5246390/
#
# --- Processing URL 24/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/mangalagaur-festival-nashik-markets-crowded-for-shopping-sud-02-5246273/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# मंगळागौरीची चाहूल बाजारपेठेसाठी उत्साहवर्धक, आर्थिक उलाढालीला चालना मिळण्याची आशा
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/mangalagaur-festival-nashik-markets-crowded-for-shopping-sud-02-5246273/
#
# --- Processing URL 25/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/video-of-manikrao-kokater-playing-rummy-increased-pressure-from-opposition-and-farmers-organizations-for-resignation-ajit-pawar-sported-him-sud-02-5246096/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# अजित पवारांकडून माणिक कोकाटेंना अभय कसे मिळाले…
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/video-of-manikrao-kokater-playing-rummy-increased-pressure-from-opposition-and-farmers-organizations-for-resignation-ajit-pawar-sported-him-sud-02-5246096/
#
# --- Processing URL 26/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/nashik-since-online-rummy-began-i-havent-played-rummy-minister-manikrao-kokate-opposes-allegations-sud-02-5246029/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# माणिक कोकाटे यांचा ऑनलाईन रमीचा अभ्यास काय ?
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/nashik-since-online-rummy-began-i-havent-played-rummy-minister-manikrao-kokate-opposes-allegations-sud-02-5246029/
#
# --- Processing URL 27/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/jalgaon-ncp-leaders-express-regret-over-ajit-pawar-missed-cm-post-in-2004-rds-00-5245629/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# अजितदादांचे २१ वर्षांपूर्वी हुकले मुख्यमंत्रीपद; जळगावमधील पदाधिकाऱ्यांना त्याची अजुनही खदखद…
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/jalgaon-ncp-leaders-express-regret-over-ajit-pawar-missed-cm-post-in-2004-rds-00-5245629/
#
# --- Processing URL 28/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/nandurbar-solar-project-scam-in-tribal-schools-sparks-probe-rds-00-5245464/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# नंदुरबार जिल्ह्यात १२ शासकीय आश्रमशाळांमध्ये सौर वीज प्रकल्पात गैरव्यवहार; तपासणी करण्याचा निर्णय
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/nandurbar-solar-project-scam-in-tribal-schools-sparks-probe-rds-00-5245464/
#
# --- Processing URL 29/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/jalgaon-zilla-parishad-and-panchayat-samiti-draft-faces-public-backlash-rds-00-5245410/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# जिल्हा परिषद-पंचायत समिती निवडणूक; जळगाव जिल्ह्यात हरकतींचा पाऊस
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/jalgaon-zilla-parishad-and-panchayat-samiti-draft-faces-public-backlash-rds-00-5245410/
#
# --- Processing URL 30/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/jalgaon-soybean-crop-hit-by-late-sowing-and-lack-of-sunlight-rds-00-5245289/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# उशिरा पेरणी, मर्यादित पाऊस, ढगाळ हवामान; जळगावमध्ये सोयाबीन पीक संकटात
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/jalgaon-soybean-crop-hit-by-late-sowing-and-lack-of-sunlight-rds-00-5245289/
#
# --- Processing URL 31/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/silver-prices-continue-rising-in-jalgaon-rs-1-lakh-18-thousand-450-per-kg-with-gst-on-tuesday-sud-02-5246210/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# जळगावमध्ये चांदीचा तोरा… मंगळवारी गाठला नवा उच्चांक
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/silver-prices-continue-rising-in-jalgaon-rs-1-lakh-18-thousand-450-per-kg-with-gst-on-tuesday-sud-02-5246210/
#
# --- Processing URL 32/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/video-of-manikrao-kokater-playing-rummy-increased-pressure-from-opposition-and-farmers-organizations-for-resignation-ajit-pawar-sported-him-sud-02-5246096/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# अजित पवारांकडून माणिक कोकाटेंना अभय कसे मिळाले…
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/video-of-manikrao-kokater-playing-rummy-increased-pressure-from-opposition-and-farmers-organizations-for-resignation-ajit-pawar-sported-him-sud-02-5246096/
#
# --- Processing URL 33/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/nashik-since-online-rummy-began-i-havent-played-rummy-minister-manikrao-kokate-opposes-allegations-sud-02-5246029/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# माणिक कोकाटे यांचा ऑनलाईन रमीचा अभ्यास काय ?
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/nashik-since-online-rummy-began-i-havent-played-rummy-minister-manikrao-kokate-opposes-allegations-sud-02-5246029/
#
# --- Processing URL 34/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/congress-mp-dr-shobha-bachhav-meeting-with-rajkumar-rawal-congress-upset-local-congress-sud-02-5245820/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# भाजपचे जयकुमार रावल यांच्या गढीवर डाॅ. शोभा बच्छाव यांचे चहापाणी…काँग्रेसला धास्ती
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/congress-mp-dr-shobha-bachhav-meeting-with-rajkumar-rawal-congress-upset-local-congress-sud-02-5245820/
#
# --- Processing URL 35/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/jalgaon-ncp-leaders-express-regret-over-ajit-pawar-missed-cm-post-in-2004-rds-00-5245629/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# अजितदादांचे २१ वर्षांपूर्वी हुकले मुख्यमंत्रीपद; जळगावमधील पदाधिकाऱ्यांना त्याची अजुनही खदखद…
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/jalgaon-ncp-leaders-express-regret-over-ajit-pawar-missed-cm-post-in-2004-rds-00-5245629/
#
# --- Processing URL 36/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/jalgaon-zilla-parishad-and-panchayat-samiti-draft-faces-public-backlash-rds-00-5245410/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# जिल्हा परिषद-पंचायत समिती निवडणूक; जळगाव जिल्ह्यात हरकतींचा पाऊस
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/jalgaon-zilla-parishad-and-panchayat-samiti-draft-faces-public-backlash-rds-00-5245410/
#
# --- Processing URL 37/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/nashik-hotels-deny-honeytrap-allegations-blame-illegal-villa-and-resort-rds-00-5245231/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# हनीट्रॅपसारखे गैरप्रकार… नाशिक हॉटेल व्यावसायिक संघटना काय म्हणते ?
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/nashik-hotels-deny-honeytrap-allegations-blame-illegal-villa-and-resort-rds-00-5245231/
#
# --- Processing URL 38/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/girish-mahajan-reaction-after-allegations-of-connection-with-prafulla-lodha-jalgaon-amy-95-5244506/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# जो करेल तो भरेल…प्रफुल्ल लोढाशी संबंधाच्या आरोपानंतर गिरीश महाजन यांची प्रतिक्रिया
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/girish-mahajan-reaction-after-allegations-of-connection-with-prafulla-lodha-jalgaon-amy-95-5244506/
#
# --- Processing URL 39/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/three-people-died-in-separate-incidents-after-falling-into-water-amy-95-5244442/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# पाण्यात पडल्याने वेगवेगळ्या घटनांमध्ये तीन जणांचा मृत्यू
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/three-people-died-in-separate-incidents-after-falling-into-water-amy-95-5244442/
#
# --- Processing URL 40/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/mp-sanjay-raut-demands-cbi-inquiry-into-girish-mahajan-praful-lodha-photo-ajlgaon-amy-95-5244441/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# प्रफुल्ल लोढा याने भरविलेला ‘पेढा’ गिरीश महाजन यांना पडणार का महाग ?
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/mp-sanjay-raut-demands-cbi-inquiry-into-girish-mahajan-praful-lodha-photo-ajlgaon-amy-95-5244441/
#
# --- Processing URL 41/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/who-are-the-four-mps-involved-in-sanjay-raut-honeytrap-allegations-anshik-news-amy-95-5244352/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# संजय राऊत यांच्या हनीट्रॅप आरोपातील चार खासदार कोण ?
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/nashik/who-are-the-four-mps-involved-in-sanjay-raut-honeytrap-allegations-anshik-news-amy-95-5244352/
#
# --- Processing URL 42/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/what-is-the-reason-for-the-consumer-panchayat-welcoming-private-companies-including-tata-power-to-the-state-amy-95-5243949/
# Successfully fetched the initial HTML content.
# --- Page Title ---

# Successfully fetched the initial HTML content.
# --- Page Title ---
# बीड पोलीस अधीक्षक कार्यालयासमोरच महादेव मुंडेंच्या कुटुंबीयांचा आत्मदहनाचा प्रयत्न
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/aurangabad/mahadev-munde-family-attempts-self-immolation-outside-beed-sp-office-ocd-94-5233802/
#
# --- Processing URL 81/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/aurangabad/shankarrao-chavan-memorial-statue-neglect-issue-poor-condition-near-statue-area-in-paithan-vsd-99-5231091/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# पैठणमध्ये शंकरराव चव्हाण यांच्या पुतळा परिसराची दुरवस्था
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/aurangabad/shankarrao-chavan-memorial-statue-neglect-issue-poor-condition-near-statue-area-in-paithan-vsd-99-5231091/
#
# --- Processing URL 82/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/aurangabad/parbhani-parent-dies-after-assault-over-tc-locals-demand-justice-ocd-94-5231027/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# संस्थाचालक दाम्पत्याला तत्काळ अटक करण्याच्या मागणीसाठी परभणीत मोर्चा
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/aurangabad/parbhani-parent-dies-after-assault-over-tc-locals-demand-justice-ocd-94-5231027/
#
# --- Processing URL 83/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/aurangabad/latur-police-seize-md-drugs-illegal-pistol-three-arrested-in-local-crime-branch-action-vsd-99-5222564/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# लातूरमध्ये एमडी ड्रग्ज, गावठी पिस्टलसह आठ लाखांचा मुद्देमाल जप्त; तिघांवर गुन्हा
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/aurangabad/latur-police-seize-md-drugs-illegal-pistol-three-arrested-in-local-crime-branch-action-vsd-99-5222564/
#
# --- Processing URL 84/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/aurangabad/parli-vaijnath-jyotirling-temple-land-encroachment-dispute-housing-approval-controversy-vsd-99-5222416/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# वैद्यनाथ देवस्थानच्या जमिनीवर घरकुलांचे वाटप; परळीतील पुजाऱ्यांचा आरोप
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/aurangabad/parli-vaijnath-jyotirling-temple-land-encroachment-dispute-housing-approval-controversy-vsd-99-5222416/
#
# --- Processing URL 85/85 ---
#
# Attempting to fetch content from: https://www.loksatta.com/aurangabad/chhatrapati-sambhajinagar-anti-corruption-department-team-catches-majalgaon-municipality-chief-officer-taking-rs-6-lakh-amy-95-5220046/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# माजलगाव नगरपालिकेच्या मुख्याधिकाऱ्यांनी बारा लाख लाच मागितली; सहा लाख घेताना सापळ्यात अडकले
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find a common article content div (e.g., 'article-content', 'story-content', 'article-body').
# Please inspect the website's HTML structure to find the correct selector for this URL.
#
# Failed to scrape content from: https://www.loksatta.com/aurangabad/chhatrapati-sambhajinagar-anti-corruption-department-team-catches-majalgaon-municipality-chief-officer-taking-rs-6-lakh-amy-95-5220046/
#
# All scraped content saved to 'links_file2_data_scrapped_24jul.txt'

# %% [markdown]
# Scrapper for Loksatta

# %%
import requests
from bs4 import BeautifulSoup
import os
import datetime

# Define a User-Agent header to mimic a web browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

def scrape_article(url):
    """
    Scrapes the title and main article content from a given URL.

    Args:
        url (str): The URL of the article to scrape.

    Returns:
        tuple: A tuple containing (title_text, article_text) if successful,
               otherwise (None, None). Prints error messages on failure.
    """
    print(f"\nAttempting to fetch content from: {url}")
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)

        soup = BeautifulSoup(response.text, 'html.parser')

        print("Successfully fetched the initial HTML content.")

        # --- Extracting Title ---
        article_title_element = soup.find('h1')
        title_text = article_title_element.get_text(strip=True) if article_title_element else "No title found"
        print(f"--- Page Title ---\n{title_text}\n------------------")

        # --- Extracting Article Content ---
        print("--- Attempting to extract Marathi News Content ---")

        article_content_container = None

        # Strategy 1: Target div with id="pcl-full-content" (most reliable for recent Loksatta structure)
        article_content_container = soup.find('div', id='pcl-full-content')
        if article_content_container:
            print("Strategy 1: Found content using ID 'pcl-full-content'.")
        else:
            # Fallback Strategy 2: Target div with class="post-content" (parent of pcl-full-content)
            post_content_div = soup.find('div', class_='post-content')
            if post_content_div:
                article_content_container = post_content_div
                print("Strategy 2: Found content using class 'post-content'.")
            else:
                # Fallback Strategy 3: Original ID for some article types (e.g., regional news from earlier checks)
                article_content_container = soup.find('div', id='dv-full-story-content')
                if article_content_container:
                    print("Strategy 3: Found content using ID 'dv-full-story-content'.")
                else:
                    # Fallback Strategy 4: Common 'df-content' class, then specifically for 'full-story-content' inside it
                    # (This was found for some editorial pages)
                    df_content_div = soup.find('div', class_='df-content')
                    if df_content_div:
                        nested_full_story = df_content_div.find('div', class_='full-story-content')
                        if nested_full_story:
                            article_content_container = nested_full_story
                            print("Strategy 4: Found content using class 'full-story-content' within 'df-content'.")
                        else:
                            article_content_container = df_content_div
                            print("Strategy 4: Found content using class 'df-content' (no specific nested div).")


        article_text = ""
        if article_content_container:
            paragraphs = article_content_container.find_all('p')
            article_text_parts = []
            for p in paragraphs:
                p_text = p.get_text(strip=True)
                # Filter out very short strings that might be empty, captions, or ads.
                # Adjust '20' as needed based on content.
                if len(p_text) > 20:
                    article_text_parts.append(p_text)

            article_text = "\n\n".join(article_text_parts)

            if article_text:
                print("\nArticle Content Found (first 500 characters):")
                print(article_text[:500] + "..." if len(article_text) > 500 else article_text)
                print("\n--- End of Article Content Snippet ---")
            else:
                print(f"No readable text paragraphs found within the identified content area.")
        else:
            print("Could not find any suitable article content div using defined strategies.")
            print("Manual inspection of the website's HTML structure is recommended for this URL.")

        return title_text, article_text

    except requests.exceptions.HTTPError as errh:
        print(f"HTTP Error for {url}: {errh}")
    except requests.exceptions.ConnectionError as errc:
        print(f"Error Connecting to {url}: {errc}")
    except requests.exceptions.Timeout as errt:
        print(f"Timeout Error for {url}: {errt}")
    except requests.exceptions.RequestException as err:
        print(f"An unexpected error occurred for {url}: {err}")
    return None, None

if __name__ == "__main__":
    # Define the name of your input file containing URLs (one URL per line)
    urls_input_file = "/content/links_data_scrapping_24jul.txt" # <--- IMPORTANT: Create this file!

    # Define the name of your output file
    output_file_name = "links_scraped_articles_output24jul.txt"

    # --- Read URLs from the input file ---
    urls_to_scrape = []
    if os.path.exists(urls_input_file):
        with open(urls_input_file, 'r', encoding='utf-8') as f:
            for line in f:
                url = line.strip() # Remove leading/trailing whitespace (like newlines)
                if url: # Only add non-empty lines
                    urls_to_scrape.append(url)
        print(f"Found {len(urls_to_scrape)} URLs in '{urls_input_file}'.")
    else:
        print(f"Error: Input file '{urls_input_file}' not found. Please create it with one URL per line.")
        exit() # Exit if the input file doesn't exist

    if not urls_to_scrape:
        print(f"The input file '{urls_input_file}' is empty or contains no valid URLs. Exiting.")
        exit()

    # --- Scrape and Save to a single output file ---
    try:
        with open(output_file_name, "w", encoding="utf-8") as out_f: # 'w' to overwrite, 'a' to append
            for i, url in enumerate(urls_to_scrape):
                print(f"\n--- Processing URL {i+1}/{len(urls_to_scrape)}: {url} ---")
                title, content = scrape_article(url)

                # Write to the file
                out_f.write(f"--- Article {i+1} ---\n")
                out_f.write(f"URL: {url}\n") # Include the URL for reference

                if title:
                    out_f.write(f"Title: {title}\n")
                else:
                    out_f.write("Title: Not found\n")

                if content:
                    out_f.write(f"Content:\n{content}\n\n")
                else:
                    out_f.write("Content: Failed to extract content.\n\n")

                out_f.write("=" * 80 + "\n\n") # Use a clear separator between articles

        print(f"\nAll scraped content saved to '{output_file_name}'")

    except IOError as e:
        print(f"Error writing to file '{output_file_name}': {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
# Out:
# Found 110 URLs in '/content/links_data_scrapping_24jul.txt'.
#
# --- Processing URL 1/110: https://www.loksatta.com/nashik/jalgoan-after-steady-rise-gold-and-silver-prices-dropped-on-thursday-giving-relief-to-buyers-sud-02-5251657/ ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/jalgoan-after-steady-rise-gold-and-silver-prices-dropped-on-thursday-giving-relief-to-buyers-sud-02-5251657/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# जळगावमध्ये सोने व चांदी इतके स्वस्त…
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# जळगाव: शहरातील सुवर्ण बाजारात सोने व चांदीच्या दरात सातत्याने वाढ होत असताना, बुधवारी सोन्याच्या दरात प्रति १० ग्रॅम ११३३ रूपये आणि चांदीच्या दरात प्रति किलो २०६० रूपयांची वाढ नोंदविण्यात आली होती. दरवाढीनंतर विशेषतः चांदीने एक लाख २० हजार ५१० रूपयांचा नवीन उच्चांकही गाठला होता. मात्र, गुरूवारी सकाळी दोन्ही धातुंच्या किमतीत मोठी घट झाल्याने ग्राहकांसह व्यावसायिकांना दिलासा मिळाला.
#
# जळगावमध्ये मंगळवारी चांदीचे दर जीएसटीसह प्रति किलो एक लाख १८ हजार ४५० रूपयांपर्यंत होते. दुसऱ्या दिवशी बुधवारी २०६०...
#
# --- End of Article Content Snippet ---
#
# --- Processing URL 2/110: https://www.loksatta.com/nashik/nashik-divisional-commissioner-dr-praveen-gedam-decided-to-cancel-non-creamy-layer-certificate-of-dismissed-ias-trainee-pooja-khedkar-sud-02-5251462/ ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/nashik-divisional-commissioner-dr-praveen-gedam-decided-to-cancel-non-creamy-layer-certificate-of-dismissed-ias-trainee-pooja-khedkar-sud-02-5251462/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# दबावातून पूजा खेडकर यांचे प्रमाणपत्र रद्द… डाॅ. प्रवीण गेडाम यांच्यावर दिलीप खेडकर यांचे कोणते आक्षेप ?
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# नाशिक: भारतीय प्रशासकीय सेवेतील (आयएएस) बडतर्फ प्रशिक्षणार्थी पूजा खेडकर यांचे ‘नॉन क्रिमिलेअर’ प्रमाणपत्र रद्द करण्याचा निर्णय नाशिक विभागीय आयुक्त डॉ. प्रवीण गेडाम यांनी घेतला. कोट्यवधींची संपत्ती व महागडी वाहने असताना ‘नॉन क्रिमिलेअर’ प्रमाणपत्र त्यांनी मिळवल्याच्या आक्षेपात तथ्य आढळल्याने विभागीय आयुक्तांनी हे प्रमाणपत्र रद्द केले. तथापि, नाशिकचे विभागीय आयुक्त डॉ. प्रवीण गेडाम यांच्या या निर्णयावर पूजा यांचे वडील दिलीप खेडकर यांनी आक्षेप घेतला आहे. विभागीय आयुक्तांनी चौकशीची प्रक्रिया चुकीच...
#
# --- End of Article Content Snippet ---
#
# --- Processing URL 3/110: https://www.loksatta.com/nashik/prafulla-lodhas-son-pawan-lodha-denied-all-three-cases-filed-against-his-father-said-are-false-we-have-no-connection-with-honey-trap-sud-02-5251421/ ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/prafulla-lodhas-son-pawan-lodha-denied-all-three-cases-filed-against-his-father-said-are-false-we-have-no-connection-with-honey-trap-sud-02-5251421/
# Successfully fetched the initial HTML content.
# --- Page Title ---
#

# Successfully fetched the initial HTML content.
# --- Page Title ---
# जो करेल तो भरेल…प्रफुल्ल लोढाशी संबंधाच्या आरोपानंतर गिरीश महाजन यांची प्रतिक्रिया
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# जळगाव– हनी ट्रॅप प्रकरणातील संशयित प्रफुल्ल लोढा याच्याशी मंत्री गिरीश महाजन यांचे जवळचे संबंध असल्याचा आरोप आमदार एकनाथ खडसे यांनी केला आहे. तर लोढा हा महाजन यांना पेढा भरवितानाच्या छायाचित्राची सीबीआय चौकशी करण्याची मागणी खासदार संजय राऊत यांनी केली आहे. या पार्श्वभूमीवर लोढा याने काय केले आहे किंवा काय केले नाही, याची चौकशी पोलिसांकडून सुरू आहे. जो करेल तो भरेल, अशी प्रतिक्रिया मंत्री महाजन यांनी दिली आहे.
#
# जामनेर तालुक्यातील मूळ रहिवाशी असलेल्या ६२ वर्षीय प्रफुल्ल लोढा याच्या विरोधात मुंबईत ...
#
# --- End of Article Content Snippet ---
#
# --- Processing URL 39/110: https://www.loksatta.com/nashik/three-people-died-in-separate-incidents-after-falling-into-water-amy-95-5244442/ ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/three-people-died-in-separate-incidents-after-falling-into-water-amy-95-5244442/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# पाण्यात पडल्याने वेगवेगळ्या घटनांमध्ये तीन जणांचा मृत्यू
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# नाशिक –जिल्ह्यात दमदार पावसामुळे धरण, तलावासह अन्य पाण्याची ठिकाणे भरली आहेत. जिल्ह्यात अशा तीन वेगवेगळ्या ठिकाणी पाण्यात पडल्याने तीन जणांचा मृत्यू झाला आहे. याप्रकरणी पोलीस ठाण्यात नोंद करण्यात आली आहे.
#
# नांदगाव तालुक्यातील पोही येथील रमेश मोरे (५०) हे मन्याड नदीपात्रातून शेतात वीज जोडणीसाठी विद्युत वायर ओढत असतांना पाय घसरून ते नदीपात्रात पडले. हा प्रकार परिसरातील अन्य लोकांच्या लक्षात येताच त्यांनी मोरे यांना पाण्यातून बाहेर काढले. रुग्णवाहिकेतून त्यांना नांदगाव ग्रामीण रुग्णालयात दाखल करण्य...
#
# --- End of Article Content Snippet ---
#
# --- Processing URL 40/110: https://www.loksatta.com/nashik/mp-sanjay-raut-demands-cbi-inquiry-into-girish-mahajan-praful-lodha-photo-ajlgaon-amy-95-5244441/ ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/mp-sanjay-raut-demands-cbi-inquiry-into-girish-mahajan-praful-lodha-photo-ajlgaon-amy-95-5244441/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# प्रफुल्ल लोढा याने भरविलेला ‘पेढा’ गिरीश महाजन यांना पडणार का महाग ?
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# जळगाव –बहुचर्चित हनी ट्रॅप प्रकरणी अटकेत असलेल्या संशयित प्रफुल्ल लोढा याच्या विरोधात मुंबईत काही गुन्हे दाखल असताना, लोढा हा यापूर्वी मंत्री गिरीश महाजन यांना पेढा भरवित असल्याचे छायाचित्र विरोधकांच्या हाती लागले आहे. त्याचा वापर करून महायुतीला कोंडीत पकडण्याची आयती संधी ठाकरे गटाचे नेते खासदार संजय राऊत यांनी साधली असून, त्या वादग्रस्त छायाचित्राची सीबीआय चौकशी करण्याची मागणीही त्यांनी केली आहे.
#
# जामनेर तालुक्यातील मूळ रहिवाशी असलेल्या ६२ वर्षीय प्रफुल्ल लोढा याचा मुंबईतील चकाला परिसरात चकाला ...
#
# --- End of Article Content Snippet ---
#
# ...
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# Jagdeep Dhankhar Resigns : संसदेचं पावसाळी अधिवेशन सुरू झाल्यानंतर पहिल्या दिवशी मोठ्या घडामोडी पाहायला मिळाल्या. या अधिवेशनाच्या पहिल्याच दिवशी उपराष्ट्रपती जगदीप धनखड यांनी आपल्या पदाचा राजीनामा दिला. खरं तर धनखड यांनी प्रकृतीच्या कारणास्तव राजीनामा देण्याचा निर्णय घेतल्याचं सांगितलं असलं तरी त्यांच्या राजीनाम्यावरून राजकीय वर्तुळात वेगवेगळ्या चर्चा सुरू आहेत. जगदीप धनखड यांनी स्वत:हून राजीनामा दिला की त्यांना राजीनामा द्यायला लावला? असे अनेक सवाल उपस्थित करण्यात येत आहेत.
#
# जगदीप धनखड यांनी रा...
#
# --- End of Article Content Snippet ---
#
# --- Processing URL 104/110: https://www.loksatta.com/nashik/nashik-divisional-commissioner-dr-praveen-gedam-decided-to-cancel-non-creamy-layer-certificate-of-dismissed-ias-trainee-pooja-khedkar-sud-02-5251462/ ---
#
# Attempting to fetch content from: https://www.loksatta.com/nashik/nashik-divisional-commissioner-dr-praveen-gedam-decided-to-cancel-non-creamy-layer-certificate-of-dismissed-ias-trainee-pooja-khedkar-sud-02-5251462/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# दबावातून पूजा खेडकर यांचे प्रमाणपत्र रद्द… डाॅ. प्रवीण गेडाम यांच्यावर दिलीप खेडकर यांचे कोणते आक्षेप ?
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# नाशिक: भारतीय प्रशासकीय सेवेतील (आयएएस) बडतर्फ प्रशिक्षणार्थी पूजा खेडकर यांचे ‘नॉन क्रिमिलेअर’ प्रमाणपत्र रद्द करण्याचा निर्णय नाशिक विभागीय आयुक्त डॉ. प्रवीण गेडाम यांनी घेतला. कोट्यवधींची संपत्ती व महागडी वाहने असताना ‘नॉन क्रिमिलेअर’ प्रमाणपत्र त्यांनी मिळवल्याच्या आक्षेपात तथ्य आढळल्याने विभागीय आयुक्तांनी हे प्रमाणपत्र रद्द केले. तथापि, नाशिकचे विभागीय आयुक्त डॉ. प्रवीण गेडाम यांच्या या निर्णयावर पूजा यांचे वडील दिलीप खेडकर यांनी आक्षेप घेतला आहे. विभागीय आयुक्तांनी चौकशीची प्रक्रिया चुकीच...
#
# --- End of Article Content Snippet ---
#
# --- Processing URL 105/110: https://www.loksatta.com/krida/farokh-enginner-big-statement-as-stand-named-after-him-in-old-trafford-manchester-shame-that-my-achievement-not-recognised-in-my-country-bdg-99-5250797/ ---
#
# Attempting to fetch content from: https://www.loksatta.com/krida/farokh-enginner-big-statement-as-stand-named-after-him-in-old-trafford-manchester-shame-that-my-achievement-not-recognised-in-my-country-bdg-99-5250797/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# “माझ्या देशात सन्मान नाही मिळाला, ही लाजिरवाणी गोष्ट”, भारताच्या माजी क्रिकेटपटूचं मोठं वक्तव्य; इंग्लंडमधील स्टेडियमच्या स्टँडला दिलं नाव
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# मँचेस्टरमधील ओल्ड ट्रॅफर्डच्या मैदानावर भारत आणि इंग्लंड यांच्यातील चौथा कसोटी सामना खेळवला जात आहे. इंग्लंडने या सामन्याची नाणेफेक जिंकत भारताला फलंदाजीसाठी पाचारण केलं. दरम्यान भारतीय संघाने पहिल्या दिवशी ४ विकेट्स गमावत २६४ धावा केल्या आहेत. पण या सामन्यापूर्वी भारत आणि वेस्ट इंडिजच्या खेळाडूंचं नाव या स्टेडियममधील स्टँन्डला देण्यात आलं. यादरम्यान भारतीय माजी खेळाडूने आपलं दु:ख व्यक्त केलं.
#
# मँचेस्टरच्या ओल्ड ट्रॅफर्ड स्टेडियममधील एका स्टँडला माजी भारतीय यष्टिरक्षक फारुख इंजिनिअर यांचे नाव दे...
#
# --- End of Article Content Snippet ---
#
# --- Processing URL

# Successfully fetched the initial HTML content.
# --- Page Title ---
# IND vs ENG: मँचेस्टरमधला पहिला दिवस ठरला ऐतिहासिक; जयस्वाल, पंत व केएल राहुलने केले ‘हे’ विक्रम
# ------------------
# --- Attempting to extract Marathi News Content ---
# Could not find any suitable article content div using defined strategies.
# Manual inspection of the website's HTML structure is recommended for this URL.
#
# --- Processing URL 109/110: https://www.loksatta.com/pune/decision-today-on-bail-application-of-accused-who-spread-defamatory-content-about-amruta-fadnavis-pune-print-news-rbk-25-amy-95-5251419/ ---
#
# Attempting to fetch content from: https://www.loksatta.com/pune/decision-today-on-bail-application-of-accused-who-spread-defamatory-content-about-amruta-fadnavis-pune-print-news-rbk-25-amy-95-5251419/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# अमृता फडणवीस यांच्याविषयी बदनामीकारक मजकूर पसरविणाऱ्या आरोपींच्या जामीन अर्जावर आज निर्णय
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# पुणे :मुख्यमंत्री देवेंद्र फडणवीस यांची पत्नी अमृता फडणवीस यांच्याविषयी समाजमाध्यमात बदनामीकारक मजकूर प्रसारित केल्याप्रकरणी सायबर पोलीस ठाण्यात दाखल असलेल्या गुन्ह्यातील आरोपींच्या जामीन अर्जावर गुरुवारी (२४ जुलै) निर्णय होणार आहे.
#
# अमृता फडणवीस यांच्याविषयी समाजमाध्यमात बदनामीकारक मजकूर प्रसारित करण्यात आला होता. या प्रकरणात सायबर पोलीस ठाण्यात गुन्हा दाखल करण्यात आला होता. या प्रकरणात निखिल जीवन संकपाळ (वय ३६, रा. कोथरूड, मूळ रा.कोल्हापूर), दत्ता तुकाराम चौधरी (वय ३७, रा. धाराशिव), बळिराम जयव...
#
# --- End of Article Content Snippet ---
#
# --- Processing URL 110/110: https://www.loksatta.com/pune/dr-abhijit-vaidya-slams-nep-for-killing-scientific-temper-in-education-urban-naxal-tag-misuse-pune-news-vsd-99-5251417/ ---
#
# Attempting to fetch content from: https://www.loksatta.com/pune/dr-abhijit-vaidya-slams-nep-for-killing-scientific-temper-in-education-urban-naxal-tag-misuse-pune-news-vsd-99-5251417/
# Successfully fetched the initial HTML content.
# --- Page Title ---
# Urban Naxalism : “…म्हणून शहरी नक्षलवादाचा ठपका”; आरोग्य सेनेच्या प्रमुखांची सरकारवर जोरदार टीका
# ------------------
# --- Attempting to extract Marathi News Content ---
# Strategy 1: Found content using ID 'pcl-full-content'.
#
# Article Content Found (first 500 characters):
# पुणे :‘अभ्यासक्रमात पुराणकथांचा समावेश करून वैज्ञानिक दृष्टिकोन संपवण्याचा सरकारचा प्रयत्न आहे. त्रिभाषा धोरणाची सक्ती हा त्याचाच एक भाग आहे. आता कोणीही प्रश्नच विचारू नयेत म्हणून शहरी नक्षलवादाचा ठपका मारण्याचे षड्यंत्र आखण्यात आले आहे,’ अशी टीका आरोग्य सेनेचे अध्यक्ष डॉ. अभिजित वैद्य यांनी बुधवारी केली.
#
# भाई वैद्य फाउंडेशन आणि आरोग्य सेनेच्या वतीने महात्मा फुले समता प्रतिष्ठानाच्या सरचिटणीस शारदा वाडेकर यांच्या हस्ते प्राचार्या नलिनी भाई वैद्य यांच्या स्मृतीप्रीत्यर्थ दिल्या जाणाऱ्या ‘समाजाभिम...
#
# --- End of Article Content Snippet ---
#
# All scraped content saved to 'links_scraped_articles_output24jul.txt'
